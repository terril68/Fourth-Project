# %%
# !pip install "camelot-py[base]"
# Out:
# ...
# WARNING: camelot-py 0.9.0 does not provide the extra 'base'
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/terri/.pyenv/versions/3.10.3/bin/python3.10 -m pip install --upgrade pip' command.

# %%
import camelot

# %%
tables = camelot.read_pdf("data/Allegheny_County_Top_50.pdf", flavor='stream',pages='1,2')
tables
# Out:
# <TableList n=3>

# %%
tables[1].df
# Out:
#                                             0  \
# 0                            Allegheny County
# 1              Combined Government Ownerships
# 2                              Rank\nEmployer
# 3              1\nUPMC Presbyterian Shadyside
# 4                 2\nUniversity of Pittsburgh
# 5                       3\nFederal Government
# 6                              4\nPNC Bank NA
# 7             5 Western Penn Allegheny Health
# 8                          6\nGiant Eagle Inc
# 9                         7\nAllegheny County
# 10              8\nCarnegie Mellon University
# 11                        9\nAllegheny Clinic
# 12                 10 Bank of New York Mellon
# 13                 11 Wal-Mart Associates Inc
# 14           12 School District of Pittsburgh
# 15     13 University of Pittsburgh Physicians
# 16                    14 UPMC Health Plan Inc
# 17                        15 State Government
# 18         16 United States Steel Corporation
# ...

# %%
tables[1].to_csv("companies.csv", index=False)

# %%
tables[2].df
# Out:
#                                                    0  \
# 0                                   Allegheny County
# 1                                               Rank
# 2                                                  1
# 3                                                  2
# 4                                                  3
# 5                                                  4
# 6                                                  5
# 7                                                  6
# 8                                                  7
# 9                                                  8
# 10                                                 9
# 11                                                10
# 12                                                11
# 13                                                12
# 14                                                13
# 15                                                14
# 16                                                15
# ...
